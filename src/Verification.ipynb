# %% [markdown]
# ### Hardware Verification

# %% [markdown]
# #### Setup & Data Loading

# %%
import os
import numpy as np
import scipy.io as sio

# Load test matrices (11 patterns)
data = sio.loadmat("Final11Pattern.mat")
Matrix = data["Matrix"]
print(f"Matrix shape: {Matrix.shape}")

# Givens rotation order [row_p, row_q, pivot_col]
GIVENS_PAIRS = [(0, 1, 0), (0, 2, 0), (1, 2, 1)]
# Out:
# Matrix shape: (3, 3, 11)

# %% [markdown]
# #### CORDIC_PE Hardware Verification

# %%
# ============================================================
# CORDIC_PE Hardware Bit-True Model
# Format: Q5.12 signed 18-bit  —  matches CORDIC_PE.sv exactly
# ============================================================
HW_DW        = 18
HW_FRAC      = 12
HW_ITERATION = 8
HW_MASK      = (1 << HW_DW) - 1

def to_s18(v):
    """Wrap arbitrary integer to 18-bit two's complement."""
    v = int(v) & HW_MASK
    return v - (1 << HW_DW) if v >= (1 << (HW_DW - 1)) else v

def float_to_fix(f):
    """float -> Q5.12 signed 18-bit integer (truncate toward -inf)."""
    return to_s18(int(np.floor(f * (1 << HW_FRAC))))

def fix_to_float(i):
    """Q5.12 signed 18-bit integer -> float."""
    return i / (1 << HW_FRAC)

def to_hex18(v):
    """Signed integer -> hex string (2's complement, width follows HW_DW)."""
    n_digits = (HW_DW + 3) // 4
    return f"{int(v) & HW_MASK:0{n_digits}X}"

def csd_scale(v):
    """CSD 1/K approximation: (v>>>1)+(v>>>3) - ((v>>>6)+(v>>>9)), 18-bit."""
    a = to_s18((v >> 1) + (v >> 3))
    b = to_s18((v >> 6) + (v >> 9))
    return to_s18(a - b)

def hw_cordic_vectoring(in_x_fp, in_y_fp):
    """Bit-true Vectoring mode — mirrors CORDIC_PE.sv INITIAL_STAGE + VECTORING_CORE + OUTPUT_BLOCK."""
    in_x = float_to_fix(in_x_fp)
    in_y = float_to_fix(in_y_fp)

    flip = in_x < 0
    x = to_s18(-in_x) if flip else in_x
    y = to_s18(-in_y) if flip else in_y

    dir_bits = []
    for i in range(HW_ITERATION):
        dx, dy = y >> i, x >> i
        if y < 0:
            x, y = to_s18(x - dx), to_s18(y + dy)
            dir_bits.append(0)
        else:
            x, y = to_s18(x + dx), to_s18(y - dy)
            dir_bits.append(1)

    out_x = csd_scale(x)
    return fix_to_float(out_x), 0.0, {
        'flip': flip, 'dir_bits': dir_bits,
        'in_x': in_x, 'in_y': in_y,
        'out_x': out_x, 'out_y': 0,
    }

def hw_cordic_rotation(in_x_fp, in_y_fp, dir_info):
    """Bit-true Rotation mode — mirrors CORDIC_PE.sv INITIAL_STAGE + ROTATION_CORE + OUTPUT_BLOCK."""
    in_x = float_to_fix(in_x_fp)
    in_y = float_to_fix(in_y_fp)

    flip = dir_info['flip']
    x = to_s18(-in_x) if flip else in_x
    y = to_s18(-in_y) if flip else in_y

    for i, d in enumerate(dir_info['dir_bits']):
        dx, dy = y >> i, x >> i
        if d:
            x, y = to_s18(x + dx), to_s18(y - dy)
        else:
            x, y = to_s18(x - dx), to_s18(y + dy)

    ox, oy = csd_scale(x), csd_scale(y)
    return fix_to_float(ox), fix_to_float(oy), {
        'in_x': in_x, 'in_y': in_y,
        'out_x': ox, 'out_y': oy,
    }

print(f"HW Bit-True Model ready: Q{HW_DW-HW_FRAC-1}.{HW_FRAC} ({HW_DW}-bit signed)")
print(f"  Representable range : [{fix_to_float(-(1<<(HW_DW-1)))}, {fix_to_float((1<<(HW_DW-1))-1)}]")
print(f"  CORDIC iterations   : {HW_ITERATION}")
print(f"  CSD scale approx    : (>>>1)+(>>>3)-(>>>6)-(>>>9) = {1/2+1/8-1/64-1/512:.6f}")
# Out:
# HW Bit-True Model ready: Q5.12 (18-bit signed)
#   Representable range : [-32.0, 31.999755859375]
#   CORDIC iterations   : 8
#   CSD scale approx    : (>>>1)+(>>>3)-(>>>6)-(>>>9) = 0.607422

# %%
# ============================================================
# Test Pattern Generation + Golden Computation + .dat Output
# Protocol: each group = 1 Vectoring followed by N Rotations
# ============================================================
import os

test_groups = []

# (A) Real matrix data: 11 patterns x 3 Givens pairs
for s in range(Matrix.shape[2]):
    M = Matrix[:, :, s].copy()
    for p, q, col in GIVENS_PAIRS:
        rot_cols = [m for m in range(col + 1, M.shape[1])]
        test_groups.append({
            'tag': f'pat{s}_G{p}{q}c{col}',
            'vec': (float(M[p, col]), float(M[q, col])),
            'rot': [(float(M[p, m]), float(M[q, m])) for m in rot_cols],
        })

# (B) Corner cases
corners = [
    ('y_zero',    ( 5.0,   0.0),  [( 2.0,  1.0)]),
    ('x_zero',    ( 0.0,   3.0),  [( 1.0,  1.0)]),
    ('x_neg',     (-4.0,   3.0),  [( 2.0, -1.0)]),
    ('both_neg',  (-5.0,  -5.0),  [(-3.0,  2.0)]),
    ('large',     (10.0,  10.0),  [(10.0, -10.0)]),
    ('tiny',      ( 0.000244140625, 0.000244140625), [(0.000244140625, 0.0)]),
    ('neg_large', (-10.0,  8.0),  [( 6.0, -7.0), ( 1.0,  1.0)]),
    ('one_one',   ( 1.0,   1.0),  [( 1.0, -1.0)]),
]
for tag, vec, rots in corners:
    test_groups.append({'tag': tag, 'vec': vec, 'rot': rots})

# (C) Random vectors
np.random.seed(2026)
for k in range(20):
    vx, vy = np.random.uniform(-10.0, 10.0, 2)
    n_rot = np.random.randint(1, 4)
    rots = list(zip(
        np.random.uniform(-10.0, 10.0, n_rot),
        np.random.uniform(-10.0, 10.0, n_rot),
    ))
    test_groups.append({
        'tag': f'rand{k}',
        'vec': (float(vx), float(vy)),
        'rot': [(float(a), float(b)) for a, b in rots],
    })

# Flatten to ordered operation stream + compute golden with HW bit-true model
ops = []
for g in test_groups:
    vx, vy = g['vec']
    _, _, dinfo = hw_cordic_vectoring(vx, vy)
    ops.append({
        'mode': 1,
        'in_x': dinfo['in_x'], 'in_y': dinfo['in_y'],
        'gold_x': dinfo['out_x'], 'gold_y': dinfo['out_y'],
        'tag': g['tag'],
    })
    for rx, ry in g['rot']:
        _, _, rinfo = hw_cordic_rotation(rx, ry, dinfo)
        ops.append({
            'mode': 0,
            'in_x': rinfo['in_x'], 'in_y': rinfo['in_y'],
            'gold_x': rinfo['out_x'], 'gold_y': rinfo['out_y'],
            'tag': g['tag'],
        })

# Write .dat files (hex, $readmemh compatible)
DAT_DIR = os.path.join('Verification_PE', '00_TESTBED', 'src')
os.makedirs(DAT_DIR, exist_ok=True)

dat_specs = {
    'PE_InMode.dat':  [f"{op['mode']}"          for op in ops],
    'PE_InX.dat':     [to_hex18(op['in_x'])      for op in ops],
    'PE_InY.dat':     [to_hex18(op['in_y'])      for op in ops],
    'PE_GoldenX.dat': [to_hex18(op['gold_x'])    for op in ops],
    'PE_GoldenY.dat': [to_hex18(op['gold_y'])    for op in ops],
}

print(f"Writing .dat files to {DAT_DIR}/:")
for fname, lines in dat_specs.items():
    fpath = os.path.join(DAT_DIR, fname)
    with open(fpath, 'w') as f:
        f.write('\n'.join(lines) + '\n')
    print(f"  {fname:20s} : {len(lines):4d} entries")

n_vec = sum(1 for op in ops if op['mode'] == 1)
n_rot = sum(1 for op in ops if op['mode'] == 0)
print(f"\nTotal: {len(ops)} operations ({n_vec} Vectoring + {n_rot} Rotation)")
print(f"Groups: {len(test_groups)} (real={11*3}, corner={len(corners)}, random=20)")

# Preview first 20 entries
print(f"\n{'#':>4} {'M':>1} {'InX':>7} {'InY':>7} | {'GoldX':>7} {'GoldY':>7} | {'InX_fp':>9} {'InY_fp':>9} | Tag")
print("-" * 80)
for i, op in enumerate(ops[:20]):
    m = 'V' if op['mode'] else 'R'
    print(f"{i:4d} {m}  {to_hex18(op['in_x'])} {to_hex18(op['in_y'])} | "
          f"{to_hex18(op['gold_x'])} {to_hex18(op['gold_y'])} | "
          f"{fix_to_float(op['in_x']):9.4f} {fix_to_float(op['in_y']):9.4f} | {op['tag']}")
# Out:
# Writing .dat files to Verification_PE\00_TESTBED\src/:
#   PE_InMode.dat        :  165 entries
#   PE_InX.dat           :  165 entries
#   PE_InY.dat           :  165 entries
#   PE_GoldenX.dat       :  165 entries
#   PE_GoldenY.dat       :  165 entries
#
# Total: 165 operations (61 Vectoring + 104 Rotation)
# Groups: 61 (real=33, corner=8, random=20)
#
#    # M     InX     InY |   GoldX   GoldY |    InX_fp    InY_fp | Tag
# --------------------------------------------------------------------------------
#    0 V  068D3 00703 | 06916 00000 |    6.5515    0.4382 | pat0_G01c0
#    1 R  00703 002B9 | 0072F 0023D |    0.4382    0.1702 | pat0_G01c0
#    2 R  3F7A7 005E6 | 3F815 00678 |   -0.5217    0.3687 | pat0_G01c0
#    3 V  068D3 3F7A7 | 0692F 00000 |    6.5515   -0.5217 | pat0_G02c0
#    4 R  00703 005E6 | 0067D 0067A |    0.4382    0.3687 | pat0_G02c0
#    5 R  3F7A7 01AE4 | 3F56A 01A1C |   -0.5217    1.6807 | pat0_G02c0
#    6 V  002B9 005E6 | 00680 00000 |    0.1702    0.3687 | pat0_G12c1
#    7 R  005E6 01AE4 | 01AE2 005F9 |    0.3687    1.6807 | pat0_G12c1
#    8 V  01073 00F54 | 0167C 00000 |    1.0281    0.9580 | pat1_G01c0
#    9 R  00F54 015D7 | 01A16 005A6 |    0.9580    1.3650 | pat1_G01c0
#   10 R  3F96E 3F0D0 | 3F0DC 3F94F |   -0.4106   -0.9492 | pat1_G01c0
#   11 V  01073 3F96E | 011B8 00000 |    1.0281   -0.4106 | pat1_G02c0
#   12 R  00F54 3F0D0 | 013CE 3F76E |    0.9580   -0.9492 | pat1_G02c0
#   13 R  3F96E 0104B | 3F3F3 00CCA |   -0.4106    1.0183 | pat1_G02c0
#   14 V  015D7 3F0D0 | 01A9B 00000 |    1.3650   -0.9492 | pat1_G12c1
#   15 R  3F0D0 0104B | 3EA3C 004C2 |   -0.9492    1.0183 | pat1_G12c1
#   16 V  016CC 002B9 | 016F9 00000 |    1.4248    0.1702 | pat2_G01c0
#   17 R  002B9 01C25 | 005F3 01BA6 |    0.1702    1.7590 | pat2_G01c0
#   18 R  3F3FD 3E9AA | 3F180 3EB30 |   -0.7507   -1.3960 | pat2_G01c0
#   19 V  016CC 3F3FD | 019C5 00000 |    1.4248   -0.7507 | pat2_G02c0

# %% [markdown]
# #### EVD Hardware Verification

# %%
# ============================================================
# EVD Hardware Bit-True Model
# Reuses: hw_cordic_vectoring, hw_cordic_rotation, float_to_fix,
#         fix_to_float, to_hex18, to_s18, GIVENS_PAIRS
# ============================================================

# Adjustable Parameters 
PATTERN_ID   = 8        # 0~10: select pattern from Final11Pattern.mat
EVD_MAX_ITER = 7        # Number of QR iterations

# PE Trace Infrastructure
PE_TRACE_EN = False
PE_TRACE    = []

PE_LABELS = {
    0: ("PE0", "ROW0_COL1", "G01"),
    1: ("PE1", "ROW0_COL2", "G02"),
    2: ("PE2", "ROW1_COL2", "G12"),
}

def pe_log(it, phase, pe_idx, mode, seq, in_x, in_y, out_x, out_y):
    """Append one trace entry when PE_TRACE_EN is True."""
    if not PE_TRACE_EN:
        return
    PE_TRACE.append({
        'it': it, 'phase': phase, 'pe_idx': pe_idx,
        'mode': mode, 'seq': seq,
        'in_x': in_x, 'in_y': in_y,
        'out_x': out_x, 'out_y': out_y,
    })

# HW EVD Functions 

def hw_apply_givens_rows(M, p, q, col, it=-1, pe_idx=-1, phase=None):
    """Apply one Givens rotation to matrix M (in-place).
    Vectoring on pivot (p,col)/(q,col), rotation on remaining columns."""
    _, _, dir_info = hw_cordic_vectoring(M[p, col], M[q, col])
    pe_log(it, phase, pe_idx, 'V', 0,
           dir_info['in_x'], dir_info['in_y'],
           dir_info['out_x'], dir_info['out_y'])
    M[p, col] = fix_to_float(dir_info['out_x'])
    M[q, col] = 0.0

    for seq, m in enumerate(range(col + 1, M.shape[1]), start=1):
        ox, oy, rinfo = hw_cordic_rotation(M[p, m], M[q, m], dir_info)
        pe_log(it, phase, pe_idx, 'R', seq,
               rinfo['in_x'], rinfo['in_y'],
               rinfo['out_x'], rinfo['out_y'])
        M[p, m] = ox
        M[q, m] = oy

    return M, dir_info


def hw_qrd(T, it=-1):
    """QR decomposition via 3 Givens rotations. Returns R and dir_infos."""
    R = T.copy()
    dir_infos = []
    for pe_idx, (p, q, col) in enumerate(GIVENS_PAIRS):
        R, di = hw_apply_givens_rows(R, p, q, col, it=it, pe_idx=pe_idx, phase='QRD')
        dir_infos.append(di)
    return R, dir_infos


def hw_rotation_pass(M, dir_infos, columns=False, it=-1, phase=None):
    """Replay rotation on all rows (columns=False) or all columns (columns=True)."""
    M = M.copy()
    for pe_idx, ((p, q, _col), dir_info) in enumerate(zip(GIVENS_PAIRS, dir_infos)):
        if columns:
            for seq, i in enumerate(range(M.shape[0]), start=1):
                ox, oy, rinfo = hw_cordic_rotation(M[i, p], M[i, q], dir_info)
                pe_log(it, phase, pe_idx, 'R', seq,
                       rinfo['in_x'], rinfo['in_y'],
                       rinfo['out_x'], rinfo['out_y'])
                M[i, p] = ox
                M[i, q] = oy
        else:
            for seq, m in enumerate(range(M.shape[1]), start=1):
                ox, oy, rinfo = hw_cordic_rotation(M[p, m], M[q, m], dir_info)
                pe_log(it, phase, pe_idx, 'R', seq,
                       rinfo['in_x'], rinfo['in_y'],
                       rinfo['out_x'], rinfo['out_y'])
                M[p, m] = ox
                M[q, m] = oy
    return M


def hw_iterative_qr_evd(A, max_iter=EVD_MAX_ITER):
    """Bit-true iterative QR EVD. Returns (eigenvalues, U, T_final)."""
    n = A.shape[0]
    T = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            T[i, j] = fix_to_float(float_to_fix(A[i, j]))

    U = np.eye(n)

    for it in range(max_iter):
        R, dir_infos = hw_qrd(T, it=it)
        RT = R.T.copy()
        T = hw_rotation_pass(RT, dir_infos, columns=False, it=it, phase='T-UPDATE')
        U = hw_rotation_pass(U, dir_infos, columns=True,  it=it, phase='U-UPDATE')

    lam = np.diag(T)
    return lam, U, T


print(f"EVD HW Model ready (PATTERN_ID={PATTERN_ID}, Iterations={EVD_MAX_ITER})")
print(f"  CORDIC config: Q{HW_DW-HW_FRAC-1}.{HW_FRAC}, {HW_ITERATION} micro-rotations, CSD scaling")
# Out:
# EVD HW Model ready (PATTERN_ID=8, Iterations=7)
#   CORDIC config: Q5.12, 8 micro-rotations, CSD scaling

# %%
# ============================================================
# EVD Golden Generation + .dat Output
# ============================================================

A = Matrix[:, :, PATTERN_ID].astype(float)
print(f"Input Matrix (Pattern {PATTERN_ID}):")
print(A)

# Run HW bit-true EVD
lam, U, T_final = hw_iterative_qr_evd(A, EVD_MAX_ITER)

# --- Write .dat files ---
DAT_DIR = os.path.join('00_TESTBED', 'src')
os.makedirs(DAT_DIR, exist_ok=True)

# Input: 3x3 matrix, row-major (9 entries)
in_data_fix = [float_to_fix(A[i, j]) for i in range(3) for j in range(3)]

# Golden Eigenvalues: diag(T), hardware order (not sorted)
ev_fix = [float_to_fix(lam[i]) for i in range(3)]

# Golden Eigenvectors: U matrix, row-major (9 entries)
u_fix = [float_to_fix(U[i, j]) for i in range(3) for j in range(3)]

dat_files = {
    'EVD_InData.dat':   in_data_fix,
    'EVD_GoldenEV.dat': ev_fix,
    'EVD_GoldenU.dat':  u_fix,
}

print(f"\nWriting .dat files to {DAT_DIR}/:")
for fname, values in dat_files.items():
    fpath = os.path.join(DAT_DIR, fname)
    with open(fpath, 'w') as f:
        f.write('\n'.join(to_hex18(v) for v in values) + '\n')
    print(f"  {fname:20s} : {len(values):2d} entries")

# --- Preview ---
print(f"\n--- Input Matrix (hex Q5.12) ---")
for i in range(3):
    row = [to_hex18(float_to_fix(A[i, j])) for j in range(3)]
    print(f"  [{row[0]}  {row[1]}  {row[2]}]")

print(f"\n--- Eigenvalues (hardware order, not sorted) ---")
for i in range(3):
    print(f"  λ[{i}] = {to_hex18(ev_fix[i])}  ({lam[i]:.6f})")

print(f"\n--- Eigenvector Matrix U (columns = eigenvectors) ---")
for i in range(3):
    row = [f"{to_hex18(float_to_fix(U[i, j]))} ({U[i, j]:8.5f})" for j in range(3)]
    print(f"  [{row[0]}  {row[1]}  {row[2]}]")

print(f"\n--- T_final (should be ~diagonal) ---")
for i in range(3):
    row = [f"{T_final[i, j]:9.5f}" for j in range(3)]
    print(f"  [{row[0]}  {row[1]}  {row[2]}]")

# --- Sanity Check vs numpy reference ---
lam_ref, V_ref = np.linalg.eigh(A)

# Align order (match by closest eigenvalue)
idx = np.argsort(lam)
lam_sorted = lam[idx]
U_sorted = U[:, idx]

# Fix sign ambiguity
for i in range(3):
    if np.dot(V_ref[:, i], U_sorted[:, i]) < 0:
        U_sorted[:, i] *= -1

rmse_lam = np.sqrt(np.mean((lam_ref - lam_sorted) ** 2))
rmse_vec = np.sqrt(np.sum((V_ref - U_sorted) ** 2) / 9)

# Threshold relaxed to 5e-2: comparing HW bit-true (Q5.12 + CSD) vs float reference;
# the purpose is detecting gross bugs, not algorithm precision validation.
SANITY_THRESH = 5e-2
print(f"\n--- Sanity Check (vs numpy.linalg.eigh, threshold={SANITY_THRESH}) ---")
print(f"  RMSE eigenvalues : {rmse_lam:.6f}  {'PASS' if rmse_lam < SANITY_THRESH else 'FAIL'}")
print(f"  RMSE eigenvectors: {rmse_vec:.6f}  {'PASS' if rmse_vec < SANITY_THRESH else 'FAIL'}")
# Out:
# Input Matrix (Pattern 8):
# [[ 2.47783871  0.48944965  3.21411749]
#  [ 0.48944965  4.23451363 -0.84897705]
#  [ 3.21411749 -0.84897705  4.85558991]]
#
# Writing .dat files to 00_TESTBED\src/:
#   EVD_InData.dat       :  9 entries
#   EVD_GoldenEV.dat     :  3 entries
#   EVD_GoldenU.dat      :  9 entries
#
# --- Input Matrix (hex Q5.12) ---
#   [027A5  007D4  0336D]
#   [007D4  043C0  3F26A]
#   [0336D  3F26A  04DB0]
#
# --- Eigenvalues (hardware order, not sorted) ---
#   λ[0] = 07336  (7.200684)
#   λ[1] = 04685  (4.407471)
#   λ[2] = 00123  (0.071045)
#
# --- Eigenvector Matrix U (columns = eigenvectors) ---
#   [008F5 ( 0.55981)  003C1 ( 0.23462)  3F336 (-0.79932)]
#   [3FE25 (-0.11597)  00FAB ( 0.97925)  00342 ( 0.20361)]
#   [00D3C ( 0.82715)  3FFB6 (-0.01807)  00924 ( 0.57129)]
#
# --- T_final (should be ~diagonal) ---
#   [  7.20068   -0.03101    0.00049]
#   [ -0.01001    4.40747    0.00049]
#   [ -0.05029   -0.03052    0.07104]
#
# --- Sanity Check (vs numpy.linalg.eigh, threshold=0.05) ---
#   RMSE eigenvalues : 0.038927  PASS
#   RMSE eigenvectors: 0.015309  PASS

# %% [markdown]
# #### PE Trace Debug Output

# %%
# ============================================================
# PE Trace Debug Output
# Runs EVD HW model with tracing, prints per-PE I/O (hex + float)
# ============================================================

PE_TRACE_EN = True
PE_TRACE.clear()

A_trace = Matrix[:, :, PATTERN_ID].astype(float)
_ = hw_iterative_qr_evd(A_trace, EVD_MAX_ITER)

PE_TRACE_EN = False

# Phase display order follows HW cnt sequence
PHASE_ORDER = [
    ('QRD',      'QRD (HW cnt 0~2)'),
    ('U-UPDATE', 'U-UPDATE (HW cnt 3~5)'),
    ('T-UPDATE', 'T-UPDATE (HW cnt 6~8)'),
]

lines = []
for it in range(EVD_MAX_ITER):
    lines.append(f"{'='*20} Iteration {it} {'='*20}")
    it_entries = [e for e in PE_TRACE if e['it'] == it]

    for phase_key, phase_label in PHASE_ORDER:
        phase_entries = [e for e in it_entries if e['phase'] == phase_key]
        if not phase_entries:
            continue
        lines.append(f"--- Phase: {phase_label} ---")
        for e in phase_entries:
            pe_name, rtl_name, givens = PE_LABELS[e['pe_idx']]
            mode_str = 'V   ' if e['mode'] == 'V' else f"R#{e['seq']}"
            ix_h, iy_h = to_hex18(e['in_x']), to_hex18(e['in_y'])
            ox_h, oy_h = to_hex18(e['out_x']), to_hex18(e['out_y'])
            lines.append(
                f"{pe_name} ({rtl_name}, {givens}) {mode_str:4s} "
                f"InX={ix_h} InY={iy_h} | OutX={ox_h} OutY={oy_h}"
            )
    lines.append("")

output_text = '\n'.join(lines)
print(output_text)

log_path = os.path.join('00_TESTBED', 'PE_Trace.log')
with open(log_path, 'w') as f:
    f.write(output_text + '\n')
print(f"[Trace written to {log_path}]")
# Out:
# ==================== Iteration 0 ====================
# --- Phase: QRD (HW cnt 0~2) ---
# PE0 (ROW0_COL1, G01) V    InX=027A5 InY=007D4 | OutX=0286B OutY=00000
# PE0 (ROW0_COL1, G01) R#1  InX=007D4 InY=043C0 | OutX=014B4 OutY=04100
# PE0 (ROW0_COL1, G01) R#2  InX=0336D InY=3F26A | OutX=02FDD OutY=3E8C8
# PE1 (ROW0_COL2, G02) V    InX=0286B InY=0336D | OutX=0416E OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=014B4 InY=3F26A | OutX=00228 OutY=3E754
# PE1 (ROW0_COL2, G02) R#2  InX=02FDD InY=04DB0 | OutX=05AAA OutY=00A86
# PE2 (ROW1_COL2, G12) V    InX=04100 InY=3E754 | OutX=0458B OutY=00000
# PE2 (ROW1_COL2, G12) R#1  InX=3E8C8 InY=00A86 | OutX=3E68F OutY=001C3
# --- Phase: U-UPDATE (HW cnt 3~5) ---
# PE0 (ROW0_COL1, G01) R#1  InX=01000 InY=00000 | OutX=00FB5 OutY=3FCEF
# PE0 (ROW0_COL1, G01) R#2  InX=00000 InY=01000 | OutX=00312 OutY=00FB6
# PE0 (ROW0_COL1, G01) R#3  InX=00000 InY=00000 | OutX=00000 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=00FB5 InY=00000 | OutX=009BA OutY=3F3A9
# PE1 (ROW0_COL2, G02) R#2  InX=00312 InY=00000 | OutX=001E8 OutY=3FD95
# PE1 (ROW0_COL2, G02) R#3  InX=00000 InY=01000 | OutX=00C92 OutY=009E9
# PE2 (ROW1_COL2, G12) R#1  InX=3FCEF InY=3F3A9 | OutX=0016F OutY=3F35E
# PE2 (ROW1_COL2, G12) R#2  InX=00FB6 InY=3FD95 | OutX=00F93 OutY=00338
# PE2 (ROW1_COL2, G12) R#3  InX=00000 InY=009E9 | OutX=3FC89 OutY=0094B
# --- Phase: T-UPDATE (HW cnt 6~8) ---
# PE0 (ROW0_COL1, G01) R#1  InX=0416E InY=00228 | OutX=040A4 OutY=3F589
# PE0 (ROW0_COL1, G01) R#2  InX=00000 InY=0458B | OutX=00D5E OutY=04444
# PE0 (ROW0_COL1, G01) R#3  InX=00000 InY=00000 | OutX=00000 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=040A4 InY=05AAA | OutX=06F40 OutY=00561
# PE1 (ROW0_COL2, G02) R#2  InX=00D5E InY=3E68F | OutX=3F44D OutY=3E5BD
# PE1 (ROW0_COL2, G02) R#3  InX=00000 InY=001C3 | OutX=00161 OutY=00118
# PE2 (ROW1_COL2, G12) R#1  InX=3F589 InY=00561 | OutX=3F450 OutY=00164
# PE2 (ROW1_COL2, G12) R#2  InX=04444 InY=3E5BD | OutX=04927 OutY=3FF38
# PE2 (ROW1_COL2, G12) R#3  InX=00000 InY=00118 | OutX=3FF9E OutY=00109
#
# ==================== Iteration 1 ====================
# --- Phase: QRD (HW cnt 0~2) ---
# PE0 (ROW0_COL1, G01) V    InX=06F40 InY=3F450 | OutX=06FE4 OutY=00000
# PE0 (ROW0_COL1, G01) R#1  InX=3F44D InY=04927 | OutX=3ED12 OutY=047A7
# PE0 (ROW0_COL1, G01) R#2  InX=00161 InY=3FF9E | OutX=00168 OutY=3FFC3
# PE1 (ROW0_COL2, G02) V    InX=06FE4 InY=00164 | OutX=06FED OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=3ED12 InY=3FF38 | OutX=3ED0F OutY=3FF5A
# PE1 (ROW0_COL2, G02) R#2  InX=00168 InY=00109 | OutX=00169 OutY=00108
# PE2 (ROW1_COL2, G12) V    InX=047A7 InY=3FF5A | OutX=047AD OutY=00000
# PE2 (ROW1_COL2, G12) R#1  InX=3FFC3 InY=00108 | OutX=3FFC2 OutY=00109
# --- Phase: U-UPDATE (HW cnt 3~5) ---
# PE0 (ROW0_COL1, G01) R#1  InX=009BA InY=0016F | OutX=0098B OutY=00268
# PE0 (ROW0_COL1, G01) R#2  InX=001E8 InY=00F93 | OutX=00059 OutY=00FB2
# PE0 (ROW0_COL1, G01) R#3  InX=00C92 InY=3FC89 | OutX=00CDB OutY=3FDCF
# PE1 (ROW0_COL2, G02) R#1  InX=0098B InY=3F35E | OutX=00976 OutY=3F34C
# PE1 (ROW0_COL2, G02) R#2  InX=00059 InY=00338 | OutX=0005F OutY=00338
# PE1 (ROW0_COL2, G02) R#3  InX=00CDB InY=0094B | OutX=00CEC OutY=00936
# PE2 (ROW1_COL2, G12) R#1  InX=00268 InY=3F34C | OutX=0027F OutY=3F350
# PE2 (ROW1_COL2, G12) R#2  InX=00FB2 InY=00338 | OutX=00FAF OutY=00355
# PE2 (ROW1_COL2, G12) R#3  InX=3FDCF InY=00936 | OutX=3FDBE OutY=00933
# --- Phase: T-UPDATE (HW cnt 6~8) ---
# PE0 (ROW0_COL1, G01) R#1  InX=06FED InY=3ED0F | OutX=07149 OutY=3F849
# PE0 (ROW0_COL1, G01) R#2  InX=00000 InY=047AD | OutX=3F8DD OutY=04759
# PE0 (ROW0_COL1, G01) R#3  InX=00000 InY=00000 | OutX=00000 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=07149 InY=00169 | OutX=07151 OutY=0009D
# PE1 (ROW0_COL2, G02) R#2  InX=3F8DD InY=3FFC2 | OutX=3F8DC OutY=3FFCF
# PE1 (ROW0_COL2, G02) R#3  InX=00000 InY=00109 | OutX=00002 OutY=0010A
# PE2 (ROW1_COL2, G12) R#1  InX=3F849 InY=0009D | OutX=3F848 OutY=00090
# PE2 (ROW1_COL2, G12) R#2  InX=04759 InY=3FFCF | OutX=0475E OutY=0004F
# PE2 (ROW1_COL2, G12) R#3  InX=00000 InY=0010A | OutX=3FFFF OutY=0010D
#
# ==================== Iteration 2 ====================
# --- Phase: QRD (HW cnt 0~2) ---
# PE0 (ROW0_COL1, G01) V    InX=07151 InY=3F848 | OutX=0719D OutY=00000
# PE0 (ROW0_COL1, G01) R#1  InX=3F8DC InY=0475E | OutX=3F3EA OutY=046B8
# PE0 (ROW0_COL1, G01) R#2  InX=00002 InY=3FFFF | OutX=00001 OutY=00000
# PE1 (ROW0_COL2, G02) V    InX=0719D InY=00090 | OutX=071A6 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=3F3EA InY=0004F | OutX=3F3E9 OutY=00064
# PE1 (ROW0_COL2, G02) R#2  InX=00001 InY=0010D | OutX=00002 OutY=0010F
# PE2 (ROW1_COL2, G12) V    InX=046B8 InY=00064 | OutX=046BD OutY=00000
# PE2 (ROW1_COL2, G12) R#1  InX=00000 InY=0010F | OutX=00001 OutY=00110
# --- Phase: U-UPDATE (HW cnt 3~5) ---
# PE0 (ROW0_COL1, G01) R#1  InX=00976 InY=0027F | OutX=00945 OutY=00326
# PE0 (ROW0_COL1, G01) R#2  InX=0005F InY=00FAF | OutX=3FF49 OutY=00FAD
# PE0 (ROW0_COL1, G01) R#3  InX=00CEC InY=3FDBE | OutX=00D0E OutY=3FEA5
# PE1 (ROW0_COL2, G02) R#1  InX=00945 InY=3F350 | OutX=0092F OutY=3F33F
# PE1 (ROW0_COL2, G02) R#2  InX=3FF49 InY=00355 | OutX=3FF4E OutY=00358
# PE1 (ROW0_COL2, G02) R#3  InX=00D0E InY=00933 | OutX=00D20 OutY=0091C
# PE2 (ROW1_COL2, G12) R#1  InX=00326 InY=3F33F | OutX=00310 OutY=3F339
# PE2 (ROW1_COL2, G12) R#2  InX=00FAD InY=00358 | OutX=00FB5 OutY=0033D
# PE2 (ROW1_COL2, G12) R#3  InX=3FEA5 InY=0091C | OutX=3FEB5 OutY=0091E
# --- Phase: T-UPDATE (HW cnt 6~8) ---
# PE0 (ROW0_COL1, G01) R#1  InX=071A6 InY=3F3E9 | OutX=0723F OutY=3FBD5
# PE0 (ROW0_COL1, G01) R#2  InX=00000 InY=046BD | OutX=3FB18 OutY=04696
# PE0 (ROW0_COL1, G01) R#3  InX=00000 InY=00000 | OutX=00000 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=0723F InY=00002 | OutX=07247 OutY=3FF35
# PE1 (ROW0_COL2, G02) R#2  InX=3FB18 InY=00001 | OutX=3FB19 OutY=0000A
# PE1 (ROW0_COL2, G02) R#3  InX=00000 InY=00110 | OutX=00001 OutY=00112
# PE2 (ROW1_COL2, G12) R#1  InX=3FBD5 InY=3FF35 | OutX=3FBD4 OutY=3FF3D
# PE2 (ROW1_COL2, G12) R#2  InX=04696 InY=0000A | OutX=0469B OutY=3FF8C
# PE2 (ROW1_COL2, G12) R#3  InX=00000 InY=00112 | OutX=00002 OutY=00113
#
# ==================== Iteration 3 ====================
# --- Phase: QRD (HW cnt 0~2) ---
# PE0 (ROW0_COL1, G01) V    InX=07247 InY=3FBD4 | OutX=07263 OutY=00000
# PE0 (ROW0_COL1, G01) R#1  InX=3FB19 InY=0469B | OutX=3F867 OutY=04662
# PE0 (ROW0_COL1, G01) R#2  InX=00001 InY=00002 | OutX=00000 OutY=00002
# PE1 (ROW0_COL2, G02) V    InX=07263 InY=3FF3D | OutX=0726B OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=3F867 InY=3FF8C | OutX=3F868 OutY=3FF7E
# PE1 (ROW0_COL2, G02) R#2  InX=00000 InY=00113 | OutX=3FFFF OutY=00114
# PE2 (ROW1_COL2, G12) V    InX=04662 InY=3FF7E | OutX=04669 OutY=00000
# PE2 (ROW1_COL2, G12) R#1  InX=00002 InY=00114 | OutX=00000 OutY=00114
# --- Phase: U-UPDATE (HW cnt 3~5) ---
# PE0 (ROW0_COL1, G01) R#1  InX=0092F InY=00310 | OutX=00910 OutY=0036A
# PE0 (ROW0_COL1, G01) R#2  InX=3FF4E InY=00FB5 | OutX=3FEB5 OutY=00FAD
# PE0 (ROW0_COL1, G01) R#3  InX=00D20 InY=3FEB5 | OutX=00D2C OutY=3FF37
# PE1 (ROW0_COL2, G02) R#1  InX=00910 InY=3F339 | OutX=00928 OutY=3F349
# PE1 (ROW0_COL2, G02) R#2  InX=3FEB5 InY=0033D | OutX=3FEB0 OutY=0033B
# PE1 (ROW0_COL2, G02) R#3  InX=00D2C InY=0091E | OutX=00D1C OutY=00937
# PE2 (ROW1_COL2, G12) R#1  InX=0036A InY=3F349 | OutX=00381 OutY=3F34F
# PE2 (ROW1_COL2, G12) R#2  InX=00FAD InY=0033B | OutX=00FA8 OutY=00358
# PE2 (ROW1_COL2, G12) R#3  InX=3FF37 InY=00937 | OutX=3FF27 OutY=00937
# --- Phase: T-UPDATE (HW cnt 6~8) ---
# PE0 (ROW0_COL1, G01) R#1  InX=0726B InY=3F868 | OutX=072A7 OutY=3FCC9
# PE0 (ROW0_COL1, G01) R#2  InX=00000 InY=04669 | OutX=3FD4F OutY=04661
# PE0 (ROW0_COL1, G01) R#3  InX=00000 InY=00000 | OutX=00000 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=072A7 InY=3FFFF | OutX=072AE OutY=000CE
# PE1 (ROW0_COL2, G02) R#2  InX=3FD4F InY=00000 | OutX=3FD4F OutY=3FFFD
# PE1 (ROW0_COL2, G02) R#3  InX=00000 InY=00114 | OutX=3FFFF OutY=00116
# PE2 (ROW1_COL2, G12) R#1  InX=3FCC9 InY=000CE | OutX=3FCC8 OutY=000C9
# PE2 (ROW1_COL2, G12) R#2  InX=04661 InY=3FFFD | OutX=04667 OutY=0007C
# PE2 (ROW1_COL2, G12) R#3  InX=00000 InY=00116 | OutX=3FFFF OutY=00117
#
# ==================== Iteration 4 ====================
# --- Phase: QRD (HW cnt 0~2) ---
# PE0 (ROW0_COL1, G01) V    InX=072AE InY=3FCC8 | OutX=072C0 OutY=00000
# PE0 (ROW0_COL1, G01) R#1  InX=3FD4F InY=04667 | OutX=3FBB7 OutY=04658
# PE0 (ROW0_COL1, G01) R#2  InX=3FFFF InY=3FFFF | OutX=3FFFF OutY=00000
# PE1 (ROW0_COL2, G02) V    InX=072C0 InY=000C9 | OutX=072CA OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=3FBB7 InY=0007C | OutX=3FBB8 OutY=00084
# PE1 (ROW0_COL2, G02) R#2  InX=3FFFF InY=00117 | OutX=00001 OutY=00118
# PE2 (ROW1_COL2, G12) V    InX=04658 InY=00084 | OutX=0465D OutY=00000
# PE2 (ROW1_COL2, G12) R#1  InX=00000 InY=00118 | OutX=00001 OutY=00119
# --- Phase: U-UPDATE (HW cnt 3~5) ---
# PE0 (ROW0_COL1, G01) R#1  InX=00928 InY=00381 | OutX=00914 OutY=003B6
# PE0 (ROW0_COL1, G01) R#2  InX=3FEB0 InY=00FA8 | OutX=3FE55 OutY=00FA2
# PE0 (ROW0_COL1, G01) R#3  InX=00D1C InY=3FF27 | OutX=00D21 OutY=3FF74
# PE1 (ROW0_COL2, G02) R#1  InX=00914 InY=3F34F | OutX=008FE OutY=3F33E
# PE1 (ROW0_COL2, G02) R#2  InX=3FE55 InY=00358 | OutX=3FE5B OutY=0035B
# PE1 (ROW0_COL2, G02) R#3  InX=00D21 InY=00937 | OutX=00D34 OutY=0091F
# PE2 (ROW1_COL2, G12) R#1  InX=003B6 InY=3F33E | OutX=003A0 OutY=3F338
# PE2 (ROW1_COL2, G12) R#2  InX=00FA2 InY=0035B | OutX=00FAA OutY=00340
# PE2 (ROW1_COL2, G12) R#3  InX=3FF74 InY=0091F | OutX=3FF85 OutY=00920
# --- Phase: T-UPDATE (HW cnt 6~8) ---
# PE0 (ROW0_COL1, G01) R#1  InX=072CA InY=3FBB8 | OutX=072E3 OutY=3FE52
# PE0 (ROW0_COL1, G01) R#2  InX=00000 InY=0465D | OutX=3FE67 OutY=0465F
# PE0 (ROW0_COL1, G01) R#3  InX=00000 InY=00000 | OutX=00000 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=072E3 InY=00001 | OutX=072EA OutY=3FF33
# PE1 (ROW0_COL2, G02) R#2  InX=3FE67 InY=00001 | OutX=3FE67 OutY=00003
# PE1 (ROW0_COL2, G02) R#3  InX=00000 InY=00119 | OutX=00001 OutY=00119
# PE2 (ROW1_COL2, G12) R#1  InX=3FE52 InY=3FF33 | OutX=3FE52 OutY=3FF36
# PE2 (ROW1_COL2, G12) R#2  InX=0465F InY=00003 | OutX=04664 OutY=3FF85
# PE2 (ROW1_COL2, G12) R#3  InX=00000 InY=00119 | OutX=00001 OutY=00119
#
# ==================== Iteration 5 ====================
# --- Phase: QRD (HW cnt 0~2) ---
# PE0 (ROW0_COL1, G01) V    InX=072EA InY=3FE52 | OutX=072F5 OutY=00000
# PE0 (ROW0_COL1, G01) R#1  InX=3FE67 InY=04664 | OutX=3FDE8 OutY=04666
# PE0 (ROW0_COL1, G01) R#2  InX=00001 InY=00001 | OutX=00000 OutY=00001
# PE1 (ROW0_COL2, G02) V    InX=072F5 InY=3FF36 | OutX=072FD OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=3FDE8 InY=3FF85 | OutX=3FDE8 OutY=3FF83
# PE1 (ROW0_COL2, G02) R#2  InX=00000 InY=00119 | OutX=3FFFF OutY=0011B
# PE2 (ROW1_COL2, G12) V    InX=04666 InY=3FF83 | OutX=0466C OutY=00000
# PE2 (ROW1_COL2, G12) R#1  InX=00001 InY=0011B | OutX=00000 OutY=0011C
# --- Phase: U-UPDATE (HW cnt 3~5) ---
# PE0 (ROW0_COL1, G01) R#1  InX=008FE InY=003A0 | OutX=008F8 OutY=003B0
# PE0 (ROW0_COL1, G01) R#2  InX=3FE5B InY=00FAA | OutX=3FE3F OutY=00FA8
# PE0 (ROW0_COL1, G01) R#3  InX=00D34 InY=3FF85 | OutX=00D36 OutY=3FF9D
# PE1 (ROW0_COL2, G02) R#1  InX=008F8 InY=3F338 | OutX=00911 OutY=3F347
# PE1 (ROW0_COL2, G02) R#2  InX=3FE3F InY=00340 | OutX=3FE3A OutY=0033E
# PE1 (ROW0_COL2, G02) R#3  InX=00D36 InY=00920 | OutX=00D26 OutY=00938
# PE2 (ROW1_COL2, G12) R#1  InX=003B0 InY=3F347 | OutX=003C8 OutY=3F34C
# PE2 (ROW1_COL2, G12) R#2  InX=00FA8 InY=0033E | OutX=00FA4 OutY=0035A
# PE2 (ROW1_COL2, G12) R#3  InX=3FF9D InY=00938 | OutX=3FF8D OutY=00939
# --- Phase: T-UPDATE (HW cnt 6~8) ---
# PE0 (ROW0_COL1, G01) R#1  InX=072FD InY=3FDE8 | OutX=07309 OutY=3FEB8
# PE0 (ROW0_COL1, G01) R#2  InX=00000 InY=0466C | OutX=3FF83 OutY=04671
# PE0 (ROW0_COL1, G01) R#3  InX=00000 InY=00000 | OutX=00000 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=07309 InY=3FFFF | OutX=07311 OutY=000CE
# PE1 (ROW0_COL2, G02) R#2  InX=3FF83 InY=00000 | OutX=3FF83 OutY=00000
# PE1 (ROW0_COL2, G02) R#3  InX=00000 InY=0011C | OutX=3FFFF OutY=0011D
# PE2 (ROW1_COL2, G12) R#1  InX=3FEB8 InY=000CE | OutX=3FEB8 OutY=000CB
# PE2 (ROW1_COL2, G12) R#2  InX=04671 InY=00000 | OutX=04676 OutY=0007F
# PE2 (ROW1_COL2, G12) R#3  InX=00000 InY=0011D | OutX=3FFFF OutY=0011E
#
# ==================== Iteration 6 ====================
# --- Phase: QRD (HW cnt 0~2) ---
# PE0 (ROW0_COL1, G01) V    InX=07311 InY=3FEB8 | OutX=0731B OutY=00000
# PE0 (ROW0_COL1, G01) R#1  InX=3FF83 InY=04676 | OutX=3FF04 OutY=04679
# PE0 (ROW0_COL1, G01) R#2  InX=3FFFF InY=3FFFF | OutX=3FFFF OutY=00000
# PE1 (ROW0_COL2, G02) V    InX=0731B InY=000CB | OutX=07324 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=3FF04 InY=0007F | OutX=3FF05 OutY=00081
# PE1 (ROW0_COL2, G02) R#2  InX=3FFFF InY=0011E | OutX=00001 OutY=00120
# PE2 (ROW1_COL2, G12) V    InX=04679 InY=00081 | OutX=0467D OutY=00000
# PE2 (ROW1_COL2, G12) R#1  InX=00000 InY=00120 | OutX=00001 OutY=00121
# --- Phase: U-UPDATE (HW cnt 3~5) ---
# PE0 (ROW0_COL1, G01) R#1  InX=00911 InY=003C8 | OutX=0090B OutY=003D8
# PE0 (ROW0_COL1, G01) R#2  InX=3FE3A InY=00FA4 | OutX=3FE1E OutY=00FA3
# PE0 (ROW0_COL1, G01) R#3  InX=00D26 InY=3FF8D | OutX=00D29 OutY=3FFA6
# PE1 (ROW0_COL2, G02) R#1  InX=0090B InY=3F34C | OutX=008F5 OutY=3F33C
# PE1 (ROW0_COL2, G02) R#2  InX=3FE1E InY=0035A | OutX=3FE25 OutY=0035E
# PE1 (ROW0_COL2, G02) R#3  InX=00D29 InY=00939 | OutX=00D3C OutY=00922
# PE2 (ROW1_COL2, G12) R#1  InX=003D8 InY=3F33C | OutX=003C1 OutY=3F336
# PE2 (ROW1_COL2, G12) R#2  InX=00FA3 InY=0035E | OutX=00FAB OutY=00342
# PE2 (ROW1_COL2, G12) R#3  InX=3FFA6 InY=00922 | OutX=3FFB6 OutY=00924
# --- Phase: T-UPDATE (HW cnt 6~8) ---
# PE0 (ROW0_COL1, G01) R#1  InX=07324 InY=3FF05 | OutX=0732D OutY=3FFD7
# PE0 (ROW0_COL1, G01) R#2  InX=00000 InY=0467D | OutX=3FF81 OutY=04681
# PE0 (ROW0_COL1, G01) R#3  InX=00000 InY=00000 | OutX=00000 OutY=00000
# PE1 (ROW0_COL2, G02) R#1  InX=0732D InY=00001 | OutX=07336 OutY=3FF32
# PE1 (ROW0_COL2, G02) R#2  InX=3FF81 InY=00001 | OutX=3FF81 OutY=00001
# PE1 (ROW0_COL2, G02) R#3  InX=00000 InY=00121 | OutX=00002 OutY=00122
# PE2 (ROW1_COL2, G12) R#1  InX=3FFD7 InY=3FF32 | OutX=3FFD7 OutY=3FF32
# PE2 (ROW1_COL2, G12) R#2  InX=04681 InY=00001 | OutX=04685 OutY=3FF83
# PE2 (ROW1_COL2, G12) R#3  InX=00000 InY=00122 | OutX=00002 OutY=00123
#
# [Trace written to 00_TESTBED\PE_Trace.log]
